-- %%
%python
df = spark.read.option("multiline", "true").json("/Volumes/country_data/country_ing/landing_zone/continent.json")
df.write.mode("overwrite").saveAsTable("country_data.country_ing.continent_ing")

-- %%
%python
df = spark.read.option("multiline", "true").json("/Volumes/country_data/country_ing/landing_zone/currency.json")
df.write.mode("overwrite").saveAsTable("country_data.country_ing.currency_ing")

-- %%
%python
df = spark.read.option("multiline", "true").json("/Volumes/country_data/country_ing/landing_zone/iso3.json")
df.write.mode("overwrite").saveAsTable("country_data.country_ing.iso3_ing")

-- %%
%python
df = spark.read.option("multiline", "true").json("/Volumes/country_data/country_ing/landing_zone/names.json")
df.write.mode("overwrite").saveAsTable("country_data.country_ing.names_ing")

-- %%
%python
df = spark.read.option("multiline", "true").json("/Volumes/country_data/country_ing/landing_zone/phone.json")
df.write.mode("overwrite").saveAsTable("country_data.country_ing.phone_ing")
